# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('I:\Text Datasets\CSV\drinks.csv')

# %% [markdown]
# #### Basic Terms
# - in statistics four basic terms are used
#  - Variables
#  - Population
#  - Sample
#  - Data

# %% [markdown]
# ##### Variables
# - Types
#     - Quantitavie Variable
#         - Discrete Variable
#         - Continuous Variable
#     - Qualitiative Variable
#         - Nominal Variable
#         - Ordinal Variable

# %%
# Variables can be any attribute that can be changeable 
a=b=c='' # These are variables

# %% [markdown]
# #### Quantitative Variable
# - A quantitative variable are those variable which can be measure or count they have two types
#     - Discrete Varialbe
#     - Continuous Varialbe

# %% [markdown]
# ####   Discrete Varialbe
# - these types of variables can be count but can't be measure
# - Example
#     - Count of Integer data not float or decimals

# %%
# This is a countable data in integer not float
df.beer_servings[0:5]
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %% [markdown]
# ##### Continous Varialbes
# - that's type of variables can be measure but not countable
#   - Example weight of a person or cgpa

# %%
# This is a float or decimal data which is the meause of totla liter of alchol
df.total_litres_of_pure_alcohol[0:5]
# Out:
# 0     0.0
# 1     4.9
# 2     0.7
# 3    12.4
# 4     5.9
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Qualitative Variables
# - these type of variables which shows the chracteristic of any thing or demographic or represents the gender
#     - Example
#         - a person is good or bad , Pakistan , Male or Female
#
# #### Nominal Variables
# - A variables which has no need of order
#     - Example
#         - Gender as Male or Female

# %%
# This is gender data which we can't make order as which should come first
tit=pd.read_csv(r'I:\Text Datasets\CSV\titanic.csv')
tit.Sex[0:2]
# Out:
# 0      male
# 1    female
# Name: Sex, dtype: object

# %% [markdown]
# #### Ordinal Variable
# - This type of data should required order
#     - Example
#         - Position of Students in a class they should as first -> second ...
#         - Smester of Bachlor Program

# %%
# this data shows the order of smsesters as first second ... 
clg_data=pd.read_csv('I:\Text Datasets\CSV\GPA.csv')
clg_data.Smesters.unique()
# Out:
# array(['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth'],
#       dtype=object)

# %% [markdown]
# ##### Population

# %%
# Population is a consisting whole objects regarding to any scenerion
# Example in a college all students are population
# in Python Example

# %%
# this data frame is considring as population because we whole select data
df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %% [markdown]
# ##### Sample

# %%
# Sample is subset of populaiton data
# like a college example if we consider 100 stdnts out 1000 then they are a somaple
# another dataset example

# %%
# This is sample out population data
df.sample(10)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 178          Tuvalu              6               41              9
# 86           Jordan              6               21              1
# 149    Saudi Arabia              0                5              0
# 164       Swaziland             90                2              2
# 191          Zambia             32               19              4
# 159    South Africa            225               76             81
# 40     Cook Islands              0              254             74
# 28    Cote d'Ivoire             37                1              7
# 45   Czech Republic            361              170            134
# 186      Uzbekistan             25              101              8
#
#      total_litres_of_pure_alcohol continent  Years
# 178                           1.0   Oceania   2005
# 86                            0.5      Asia   1913
# 149                           0.1      Asia   1976
# ...

# %% [markdown]
# ##### Data

# %%
# Data can be any thing which assign to a variable 
a=50 # so 50 is also a data
df.head(2) # this is also a data
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
#
#    total_litres_of_pure_alcohol continent  Years
# 0                           0.0      Asia   1827
# 1                           4.9    Europe   1828
